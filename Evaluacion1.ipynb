# %% [markdown]
# <a href="https://colab.research.google.com/github/022000434-star/Primera-evaluacion/blob/Develop/Evaluacion1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hagamos un modelo de regresión lineal simple con el archivo

# %%
# Importar librerías
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, confusion_matrix

# %%
# Cargar datos
df = pd.read_csv("datos_ml.csv")
print(df.head())
# Out:
#    Edad  Ingresos  Años_Estudio  Compra
# 0    25     32000            11       0
# 1    30     45000            14       1
# 2    22     28000            10       0
# 3    35     52000            16       1
# 4    28     39000            12       0

# %%
# Regresión Lineal Simple (Ingresos vs Edad)
X_simple = df[["Edad"]]
y_simple = df["Ingresos"]

x_train, x_test, y_pred_simple, y_test = train_test_split(X_simple, y_simple, test_size=None, random_state=42)

modelo_lineal_simple = LinearRegression()

# Reshape x_train si es necesario (debe ser 2D para sklearn)
if len(X_simple.shape) == 1:
  x_train = X_simple.reshape(-1, 1)

        # Entrenar el modelo
modelo_lineal_simple.fit(X_simple, y_simple)
# Out:
# LinearRegression()

# %% [markdown]
# Genera un modelo de regresión lineal de `scikit-learn` con `X_simple`, `y_simple`, usando un **80% de los datos para entrenamiento** y un `random_state=42`
#
# Guarda el modelo en la variable `modelo_lineal_simple` y genera una predicción que se almacene en `y_pred_simple`.

# %%
try:
  print("Regresión Lineal Simple:")
  print("Coeficiente:", modelo_lineal_simple.coef_[0])
  print("Intercepto:", modelo_lineal_simple.intercept_)
  print("R²:", r2_score(y_test, y_pred_simple))
except Exception as e:
  print(f"Hubo un problema con el Modelo de regresión: {e}")
# Out:
# Regresión Lineal Simple:
# Coeficiente: 1830.8146897425065
# Intercepto: -12212.368087800736
# Hubo un problema con el Modelo de regresión: Found input variables with inconsistent numbers of samples: [13, 38]

# %%
if len(X_simple) == 1:
            y_pred_simple = X_simple.reshape(-1, 1)

y_pred_simple = modelo_lineal_simple.predict(X_simple)
print(y_pred_simple)
# Out:
# [33557.99915576 42712.07260447 28065.55508653 51866.14605319
#  39050.44322499 61020.2195019  29896.36977628 44542.88729422
#  37219.62853525 53696.96074293 31727.18446602 48204.5166737
#  40881.25791473 57358.59012241 35388.8138455  50035.33136344
#  26234.74039679 59189.40481216 46373.70198396 24403.92570705
#  62851.03419164 28065.55508653 55527.77543267 39050.44322499
#  42712.07260447 33557.99915576 51866.14605319 29896.36977628
#  44542.88729422 37219.62853525 53696.96074293 31727.18446602
#  48204.5166737  40881.25791473 57358.59012241 35388.8138455
#  50035.33136344 26234.74039679 59189.40481216 46373.70198396
#  24403.92570705 62851.03419164 28065.55508653 55527.77543267
#  39050.44322499 42712.07260447 33557.99915576 51866.14605319
#  29896.36977628 44542.88729422 37219.62853525]
